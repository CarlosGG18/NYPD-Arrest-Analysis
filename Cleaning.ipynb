# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.23.2 in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\thech\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('NYPD_Arrest_Data__Year_to_Date_.csv')

# %%
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2   279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3   280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4   280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                       ROBBERY  PL 1601001          F           M
# 1                          RAPE  PL 1303501          F           K
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
# 3               DANGEROUS DRUGS  PL 2200300          M           B
# 4                FELONY ASSAULT  PL 1200502          F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               26                  0       <18        M           BLACK
# 1               77                  0     25-44        M  WHITE HISPANIC
# 2              106                  0       65+        F           WHITE
# 3               49                  0     45-64        M           BLACK
# 4               81                  2     25-44        F           BLACK
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0      996342      236149  40.814845 -73.956312
# 1     1003509      185018  40.674496 -73.930571
# 2     1026836      180689  40.662526 -73.846499
# 3     1027430      251104  40.855793 -73.843908
# 4     1002457      192292  40.694456 -73.934343
#
#                      New Georeferenced Column
# 0                POINT (-73.956312 40.814845)
# 1  POINT (-73.9305713255961 40.6744956865259)
# 2                POINT (-73.846499 40.662526)
# 3                POINT (-73.843908 40.855793)
# 4                POINT (-73.934343 40.694456)

# %% [markdown]
# ### Column Desc Decide later if this is worth keeping
#
# Arrest Key
#
# PD CD
#
# KY CD
#
# Law Code
#
# Law Cat

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63621 entries, 0 to 63620
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                63621 non-null  int64
#  1   ARREST_DATE               63621 non-null  object
#  2   PD_CD                     63619 non-null  float64
#  3   PD_DESC                   63621 non-null  object
#  4   KY_CD                     63612 non-null  float64
#  5   OFNS_DESC                 63621 non-null  object
#  6   LAW_CODE                  63621 non-null  object
#  7   LAW_CAT_CD                63219 non-null  object
#  8   ARREST_BORO               63621 non-null  object
#  9   ARREST_PRECINCT           63621 non-null  int64
#  10  JURISDICTION_CODE         63621 non-null  int64
#  11  AGE_GROUP                 63621 non-null  object
#  12  PERP_SEX                  63621 non-null  object
#  13  PERP_RACE                 63621 non-null  object
#  14  X_COORD_CD                63621 non-null  int64
#  15  Y_COORD_CD                63621 non-null  int64
#  16  Latitude                  63621 non-null  float64
#  17  Longitude                 63621 non-null  float64
#  18  New Georeferenced Column  63621 non-null  object
# dtypes: float64(4), int64(5), object(10)
# memory usage: 9.2+ MB

# %% [markdown]
# ### Checking for Missing/Duplicate Values

# %%
df.isna().sum()
# Out:
# ARREST_KEY                    0
# ARREST_DATE                   0
# PD_CD                         2
# PD_DESC                       0
# KY_CD                         9
# OFNS_DESC                     0
# LAW_CODE                      0
# LAW_CAT_CD                  402
# ARREST_BORO                   0
# ARREST_PRECINCT               0
# JURISDICTION_CODE             0
# AGE_GROUP                     0
# PERP_SEX                      0
# PERP_RACE                     0
# X_COORD_CD                    0
# Y_COORD_CD                    0
# Latitude                      0
# Longitude                     0
# New Georeferenced Column      0
# dtype: int64

# %%
missing_percentage = (df['PD_CD'].isnull().sum() / len(df['PD_CD'])) * 100
print("Percentage of missing values in 'PD_CD' column:", missing_percentage)
# Out:
# Percentage of missing values in 'PD_CD' column: 0.0031436161016016725

# %%
missing_percentage = (df['KY_CD'].isnull().sum() / len(df['KY_CD'])) * 100
print("Percentage of missing values in 'KY_CD' column:", missing_percentage)
# Out:
# Percentage of missing values in 'KY_CD' column: 0.014146272457207527

# %%
missing_percentage = (df['LAW_CAT_CD'].isnull().sum() / len(df['LAW_CAT_CD'])) * 100
print("Percentage of missing values in 'LAW_CAT' column:", missing_percentage)
# Out:
# Percentage of missing values in 'LAW_CAT' column: 0.6318668364219362

# %%
misisng_KY_CD_rows = df[df['KY_CD'].isna()]
misisng_KY_CD_rows.head(12)
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD PD_DESC  KY_CD OFNS_DESC    LAW_CODE  \
# 8       280961365  01/23/2024    NaN  (null)    NaN    (null)      (null)
# 5331    281035905  01/24/2024  777.0  (null)    NaN    (null)  PL 1950200
# 10056   280660228  01/17/2024  660.0  (null)    NaN    (null)  PL 2407800
# 20633   280346962  01/11/2024  660.0  (null)    NaN    (null)  PL 2407800
# 34105   281444571  01/31/2024  660.0  (null)    NaN    (null)  PL 2407900
# 39425   282534026  02/21/2024  777.0  (null)    NaN    (null)  PL 1950200
# 46307   282228504  02/14/2024  810.0  (null)    NaN    (null)  PL 2702100
# 51782   284173781  03/22/2024  777.0  (null)    NaN    (null)  PL 1950200
# 56233   283941614  03/18/2024    NaN  (null)    NaN    (null)      (null)
#
#       LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 8         (null)           M                5                 97     25-44
# 5331           F           K               67                  0     45-64
# 10056          M           B               42                  0       <18
# 20633          M           K               75                  0       <18
# 34105          M           M               18                  0     25-44
# 39425          F           K               67                  0     45-64
# 46307          M           K               67                  0     25-44
# 51782          F           B               40                  0     45-64
# 56233     (null)           K               67                  0     25-44
#
#       PERP_SEX                 PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 8            M                     BLACK      983903      200257  40.716337
# 5331         F                     WHITE      997897      175676  40.648859
# 10056        M            WHITE HISPANIC     1010967      238733  40.821903
# 20633        M            WHITE HISPANIC     1013001      184766  40.673773
# 34105        F                     BLACK      987171      218109  40.765336
# 39425        M                     BLACK      997897      175676  40.648859
# 46307        M  ASIAN / PACIFIC ISLANDER     1006328      177267  40.653207
# 51782        F                     WHITE     1005040      234533  40.810391
# 56233        M                     BLACK      998216      176711  40.651696
#
#        Longitude                      New Georeferenced Column
# 8     -74.001251                  POINT (-74.001251 40.716337)
# 5331  -73.950820                   POINT (-73.95082 40.648859)
# 10056 -73.903466                  POINT (-73.903466 40.821903)
# 20633 -73.896350                   POINT (-73.89635 40.673773)
# 34105 -73.989454                  POINT (-73.989454 40.765336)
# 39425 -73.950820                   POINT (-73.95082 40.648859)
# 46307 -73.920430                   POINT (-73.92043 40.653207)
# 51782 -73.924895                  POINT (-73.924895 40.810391)
# 56233 -73.949669  POINT (-73.94966875535633 40.65169649424705)

# %%
total_rows = len(df)
total_missing_count = df.isnull().sum()

for column, missing_count in total_missing_count.items():
    if missing_count > 0:
        missing_percentage = (missing_count / total_rows) * 100
        print(f"Percentage of missing values in '{column}' column: {missing_percentage:.2f}%")
        
total_missing_percentage = (total_missing_count.sum().sum() / (total_rows * len(df.columns))) * 100
print(f"Total percentage of missing values: {total_missing_percentage:.2f}%")
# Out:
# Percentage of missing values in 'PD_CD' column: 0.00%
# Percentage of missing values in 'KY_CD' column: 0.01%
# Percentage of missing values in 'LAW_CAT_CD' column: 0.63%
# Total percentage of missing values: 0.03%

# %% [markdown]
# #CHECK THE ABOVE NUMBER THEY DONT ADD UP BUT DROP ALL NULL VALUES

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Appropriating Data Types

# %%
df['ARREST_DATE'] = pd.to_datetime(df['ARREST_DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63210 entries, 0 to 63620
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                63210 non-null  int64
#  1   ARREST_DATE               63210 non-null  datetime64[ns]
#  2   PD_CD                     63210 non-null  float64
#  3   PD_DESC                   63210 non-null  object
#  4   KY_CD                     63210 non-null  float64
#  5   OFNS_DESC                 63210 non-null  object
#  6   LAW_CODE                  63210 non-null  object
#  7   LAW_CAT_CD                63210 non-null  object
#  8   ARREST_BORO               63210 non-null  object
#  9   ARREST_PRECINCT           63210 non-null  int64
#  10  JURISDICTION_CODE         63210 non-null  int64
#  11  AGE_GROUP                 63210 non-null  object
#  12  PERP_SEX                  63210 non-null  object
#  13  PERP_RACE                 63210 non-null  object
#  14  X_COORD_CD                63210 non-null  int64
#  15  Y_COORD_CD                63210 non-null  int64
#  16  Latitude                  63210 non-null  float64
#  17  Longitude                 63210 non-null  float64
#  18  New Georeferenced Column  63210 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(9)
# memory usage: 9.6+ MB

# %%
df['LAW_CAT_CD'].describe()
# Out:
# count     63210
# unique        5
# top           M
# freq      35576
# Name: LAW_CAT_CD, dtype: object

# %%
df['LAW_CAT_CD'].unique()
# Out:
# array(['F', 'M', 'V', '9', 'I'], dtype=object)

# %%
print(df['OFNS_DESC'].unique())
print(f'Total unique elements in offensive description is: {len(df["OFNS_DESC"].unique())}')
# Out:
# ['ROBBERY' 'RAPE' 'ASSAULT 3 & RELATED OFFENSES' 'DANGEROUS DRUGS'
#  'FELONY ASSAULT' 'JOSTLING' 'ARSON' 'BURGLARY' 'DANGEROUS WEAPONS'
#  'MISCELLANEOUS PENAL LAW' 'VEHICLE AND TRAFFIC LAWS' 'PETIT LARCENY'
#  'CRIMINAL TRESPASS' 'GRAND LARCENY' 'OTHER OFFENSES RELATED TO THEF'
#  'GRAND LARCENY OF MOTOR VEHICLE' 'CRIMINAL MISCHIEF & RELATED OF'
#  'OFF. AGNST PUB ORD SENSBLTY &' 'OTHER TRAFFIC INFRACTION'
#  'OFFENSES AGAINST PUBLIC ADMINI' 'DISORDERLY CONDUCT' 'SEX CRIMES'
#  'FORGERY' 'NYS LAWS-UNCLASSIFIED FELONY' 'POSSESSION OF STOLEN PROPERTY'
#  'OTHER STATE LAWS' 'MURDER & NON-NEGL. MANSLAUGHTE'
#  'INTOXICATED & IMPAIRED DRIVING' 'OFFENSES INVOLVING FRAUD'
#  'CANNABIS RELATED OFFENSES' 'OFFENSES AGAINST THE PERSON' 'FRAUDS'
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'OTHER STATE LAWS (NON PENAL LA'
#  'ENDAN WELFARE INCOMP' 'UNAUTHORIZED USE OF A VEHICLE'
#  'ADMINISTRATIVE CODE' 'GAMBLING' 'PROSTITUTION & RELATED OFFENSES'
#  "BURGLAR'S TOOLS" 'INTOXICATED/IMPAIRED DRIVING'
#  'AGRICULTURE & MRKTS LAW-UNCLASSIFIED' 'THEFT OF SERVICES'
#  'OFFENSES AGAINST PUBLIC SAFETY' 'THEFT-FRAUD'
#  'KIDNAPPING & RELATED OFFENSES' 'HARRASSMENT 2' 'MOVING INFRACTIONS'
#  'FRAUDULENT ACCOSTING' 'ESCAPE 3' 'ANTICIPATORY OFFENSES' 'KIDNAPPING'
#  'HOMICIDE-NEGLIGENT,UNCLASSIFIE' 'CHILD ABANDONMENT/NON SUPPORT'
#  'OTHER STATE LAWS (NON PENAL LAW)' 'ADMINISTRATIVE CODES'
#  'HOMICIDE-NEGLIGENT-VEHICLE' 'DISRUPTION OF A RELIGIOUS SERV'
#  'FORTUNE TELLING' 'OFFENSES RELATED TO CHILDREN']
# Total unique elements in offensive description is: 60

# %%
percentage_per_category = df['OFNS_DESC'].value_counts(normalize=True) * 100
print(percentage_per_category)
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES            14.174972
# PETIT LARCENY                           10.324316
# FELONY ASSAULT                           8.365765
# DANGEROUS DRUGS                          7.487739
# MISCELLANEOUS PENAL LAW                  6.315456
# VEHICLE AND TRAFFIC LAWS                 6.206296
# GRAND LARCENY                            4.853662
# ROBBERY                                  4.659073
# CRIMINAL MISCHIEF & RELATED OF           4.456573
# DANGEROUS WEAPONS                        3.969309
# OTHER OFFENSES RELATED TO THEF           3.523177
# OFFENSES AGAINST PUBLIC ADMINI           3.133998
# BURGLARY                                 2.529663
# OFFENSES INVOLVING FRAUD                 2.189527
# SEX CRIMES                               2.187945
# FORGERY                                  2.045562
# OFF. AGNST PUB ORD SENSBLTY &            1.800348
# POSSESSION OF STOLEN PROPERTY            1.683278
# CRIMINAL TRESPASS                        1.205505
# OTHER TRAFFIC INFRACTION                 1.118494
# INTOXICATED & IMPAIRED DRIVING           1.010916
# GRAND LARCENY OF MOTOR VEHICLE           0.889100
# OTHER STATE LAWS                         0.802088
# OFFENSES AGAINST THE PERSON              0.639139
# NYS LAWS-UNCLASSIFIED FELONY             0.631229
# MURDER & NON-NEGL. MANSLAUGHTE           0.598007
# DISORDERLY CONDUCT                       0.498339
# FRAUDS                                   0.409745
# BURGLAR'S TOOLS                          0.286347
# RAPE                                     0.278437
# UNAUTHORIZED USE OF A VEHICLE            0.238886
# CANNABIS RELATED OFFENSES                0.193007
# OTHER STATE LAWS (NON PENAL LA           0.162949
# PROSTITUTION & RELATED OFFENSES          0.148711
# GAMBLING                                 0.112324
# INTOXICATED/IMPAIRED DRIVING             0.107578
# ALCOHOLIC BEVERAGE CONTROL LAW           0.088594
# THEFT-FRAUD                              0.083847
# OFFENSES AGAINST PUBLIC SAFETY           0.080683
# ADMINISTRATIVE CODE                      0.077519
# THEFT OF SERVICES                        0.066445
# JOSTLING                                 0.055371
# ARSON                                    0.052207
# KIDNAPPING & RELATED OFFENSES            0.045879
# ENDAN WELFARE INCOMP                     0.039551
# HARRASSMENT 2                            0.033223
# HOMICIDE-NEGLIGENT,UNCLASSIFIE           0.026894
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED     0.025312
# CHILD ABANDONMENT/NON SUPPORT            0.018984
# MOVING INFRACTIONS                       0.017402
# FRAUDULENT ACCOSTING                     0.015820
# DISRUPTION OF A RELIGIOUS SERV           0.009492
# ESCAPE 3                                 0.004746
# OTHER STATE LAWS (NON PENAL LAW)         0.004746
# HOMICIDE-NEGLIGENT-VEHICLE               0.003164
# ANTICIPATORY OFFENSES                    0.003164
# KIDNAPPING                               0.003164
# OFFENSES RELATED TO CHILDREN             0.003164
# ADMINISTRATIVE CODES                     0.001582
# FORTUNE TELLING                          0.001582
# Name: proportion, dtype: float64

# %% [markdown]
# #### Due to large number of unique values will be keepin as object type as opposed to categorical

# %%
df['ARREST_BORO'].unique()
# Out:
# array(['M', 'K', 'Q', 'B', 'S'], dtype=object)

# %%
df['ARREST_BORO'] = df['ARREST_BORO'].astype('category')

# %%
df['ARREST_PRECINCT'].unique()
# Out:
# array([ 26,  77, 106,  49,  81, 113,   6,  41, 102,  69,  79,  20,  47,
#        114,  88,  17, 112,  14,  45,  32, 115,   1,  67, 120, 103,  23,
#         63,  40, 108,  18,  46,  44,  60,  52, 110,   5, 105,  48, 121,
#         83, 101,  43,  68, 104,  42,  72,  25,  71,  62,  73,  75,  84,
#         24,  94,  66,  78,  33,  34,   7,  13,  30, 109, 107,  19,  70,
#         90,  10,  50, 111,  28, 122,   9,  76,  61, 100, 123,  22],
#       dtype=int64)

# %%
df['ARREST_PRECINCT'] = df['ARREST_PRECINCT'].astype('category')

# %%
print(df['ARREST_BORO'].unique())
# Out:
# ['M', 'K', 'Q', 'B', 'S']
# Categories (5, object): ['B', 'K', 'M', 'Q', 'S']

# %%
#Originally brooklyn was under letter K as brooklyn is also known as Kings County

boro_mapping = {
    'M': 'Manhattan',
    'K': 'Brooklyn',
    'Q': 'Queens',
    'B': 'Bronx',
    'S': 'Staten Island'
}

# Rename categories using the dictionary
df['ARREST_BORO'] = df['ARREST_BORO'].cat.rename_categories(boro_mapping)

# %%
df['ARREST_BORO']
# Out:
# 0            Manhattan
# 1             Brooklyn
# 2               Queens
# 3                Bronx
# 4             Brooklyn
#              ...
# 63616         Brooklyn
# 63617        Manhattan
# 63618         Brooklyn
# 63619         Brooklyn
# 63620    Staten Island
# Name: ARREST_BORO, Length: 63210, dtype: category
# Categories (5, object): ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']

# %%
df['PERP_SEX'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
sex_mapping = {
    'M': 'Male',
    'F': 'Female'
}

# Convert 'PERP_SEX' to categorical data type
df['PERP_SEX'] = df['PERP_SEX'].astype('category')

# Rename categories using the dictionary
df['PERP_SEX'] = df['PERP_SEX'].cat.rename_categories(sex_mapping)

# %%
df['PERP_RACE'].unique()
# Out:
# array(['BLACK', 'WHITE HISPANIC', 'WHITE', 'ASIAN / PACIFIC ISLANDER',
#        'UNKNOWN', 'BLACK HISPANIC', 'AMERICAN INDIAN/ALASKAN NATIVE'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63210 entries, 0 to 63620
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                63210 non-null  int64
#  1   ARREST_DATE               63210 non-null  datetime64[ns]
#  2   PD_CD                     63210 non-null  float64
#  3   PD_DESC                   63210 non-null  object
#  4   KY_CD                     63210 non-null  float64
#  5   OFNS_DESC                 63210 non-null  object
#  6   LAW_CODE                  63210 non-null  object
#  7   LAW_CAT_CD                63210 non-null  category
#  8   ARREST_BORO               63210 non-null  category
#  9   ARREST_PRECINCT           63210 non-null  category
#  10  JURISDICTION_CODE         63210 non-null  int64
#  11  AGE_GROUP                 63210 non-null  object
#  12  PERP_SEX                  63210 non-null  category
#  13  PERP_RACE                 63210 non-null  object
#  14  X_COORD_CD                63210 non-null  int64
#  15  Y_COORD_CD                63210 non-null  int64
#  16  Latitude                  63210 non-null  float64
#  17  Longitude                 63210 non-null  float64
#  18  New Georeferenced Column  63210 non-null  object
# dtypes: category(4), datetime64[ns](1), float64(4), int64(4), object(6)
# memory usage: 8.0+ MB

# %%
df['LAW_CAT_CD'].unique()
# Out:
# array(['F', 'M', 'V', '9', 'I'], dtype=object)

# %%
print(df.loc[df['LAW_CAT_CD'] == 'M']) #Misdomener
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 2       279895750  2024-01-03  101.0                       ASSAULT 3  344.0
# 3       280809090  2024-01-19  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 6       280769124  2024-01-19  464.0                        JOSTLING  230.0
# 7       281338081  2024-01-30  101.0                       ASSAULT 3  344.0
# 15      281544391  2024-02-02  101.0                       ASSAULT 3  344.0
# ...           ...         ...    ...                             ...    ...
# 63613   283819808  2024-03-15  101.0                       ASSAULT 3  344.0
# 63616   282877412  2024-02-27  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 63617   283628088  2024-03-12  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 63619   283013910  2024-03-01  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 63620   283495531  2024-03-10  203.0            TRESPASS 3, CRIMINAL  352.0
#
#                           OFNS_DESC    LAW_CODE LAW_CAT_CD    ARREST_BORO  \
# 2      ASSAULT 3 & RELATED OFFENSES  PL 1200001          M         Queens
# 3                   DANGEROUS DRUGS  PL 2200300          M          Bronx
# 6                          JOSTLING  PL 1652501          M      Manhattan
# 7      ASSAULT 3 & RELATED OFFENSES  PL 1200001          M      Manhattan
# 15     ASSAULT 3 & RELATED OFFENSES  PL 1200001          M      Manhattan
# ...                             ...         ...        ...            ...
# 63613  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M      Manhattan
# 63616                 PETIT LARCENY  PL 1552500          M       Brooklyn
# 63617               DANGEROUS DRUGS  PL 2200300          M      Manhattan
# 63619      VEHICLE AND TRAFFIC LAWS  VTL05110A4          M       Brooklyn
# 63620             CRIMINAL TRESPASS  PL 140100A          M  Staten Island
#
#       ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 2                 106                  0       65+   Female
# 3                  49                  0     45-64     Male
# 6                   6                  0     25-44     Male
# 7                  26                  0     25-44     Male
# 15                 20                  0     45-64   Female
# ...               ...                ...       ...      ...
# 63613              13                  0     45-64     Male
# 63616              60                  0     45-64     Male
# 63617              13                  0     45-64     Male
# 63619              83                  0     25-44   Female
# 63620             123                  0     25-44     Male
#
#                             PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 2                               WHITE     1026836      180689  40.662526
# 3                               BLACK     1027430      251104  40.855793
# 6                               BLACK      984134      207984  40.737547
# 7                               BLACK      996014      236126  40.814780
# 15                              WHITE      991040      225092  40.784499
# ...                               ...         ...         ...        ...
# 63613  AMERICAN INDIAN/ALASKAN NATIVE      986930      207834  40.737133
# 63616                  WHITE HISPANIC      987154      149165  40.576100
# 63617                           BLACK      985689      208933  40.740151
# 63619                           BLACK     1007120      193913  40.698894
# 63620                           WHITE      930842      133050  40.531707
#
#        Longitude                       New Georeferenced Column
# 2     -73.846499                   POINT (-73.846499 40.662526)
# 3     -73.843908                   POINT (-73.843908 40.855793)
# 6     -74.000415                   POINT (-74.000415 40.737547)
# 7     -73.957499                    POINT (-73.957499 40.81478)
# 15    -73.975480                    POINT (-73.97548 40.784499)
# ...          ...                                            ...
# 63613 -73.990329   POINT (-73.99032932220675 40.73713251623451)
# 63616 -73.989545                     POINT (-73.989545 40.5761)
# 63617 -73.994805                   POINT (-73.994805 40.740151)
# 63619 -73.917522  POINT (-73.91752179908735 40.698893568968515)
# 63620 -74.192126                   POINT (-74.192126 40.531707)
#
# [35576 rows x 19 columns]

# %%
print(df.loc[df['LAW_CAT_CD'] == 'F']) #Felony
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       280255493  2024-01-10  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1       279805419  2024-01-02  157.0                          RAPE 1  104.0
# 4       280357135  2024-01-11  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# 5       281488967  2024-02-01  157.0                          RAPE 1  104.0
# 9       281426006  2024-01-31  155.0                          RAPE 2  104.0
# ...           ...         ...    ...                             ...    ...
# 63610   283856690  2024-03-16  503.0  CONTROLLED SUBSTANCE,INTENT TO  117.0
# 63611   284520369  2024-03-29  503.0  CONTROLLED SUBSTANCE,INTENT TO  117.0
# 63614   284409873  2024-03-27  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 63615   283436353  2024-03-08  729.0  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 63618   283387006  2024-03-07  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
#
#              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO ARREST_PRECINCT  \
# 0              ROBBERY  PL 1601001          F   Manhattan              26
# 1                 RAPE  PL 1303501          F    Brooklyn              77
# 4       FELONY ASSAULT  PL 1200502          F    Brooklyn              81
# 5                 RAPE  PL 1303501          F      Queens             113
# 9                 RAPE  PL 1303001          F       Bronx              41
# ...                ...         ...        ...         ...             ...
# 63610  DANGEROUS DRUGS  PL 2201601          F   Manhattan               9
# 63611  DANGEROUS DRUGS  PL 2201601          F   Manhattan              14
# 63614          ROBBERY  PL 1601001          F      Queens             113
# 63615          FORGERY  PL 1701501          F    Brooklyn              73
# 63618          ROBBERY  PL 160102A          F    Brooklyn              73
#
#        JURISDICTION_CODE AGE_GROUP PERP_SEX                 PERP_RACE  \
# 0                      0       <18     Male                     BLACK
# 1                      0     25-44     Male            WHITE HISPANIC
# 4                      2     25-44   Female                     BLACK
# 5                      0     25-44     Male                     BLACK
# 9                      0     18-24     Male                     BLACK
# ...                  ...       ...      ...                       ...
# 63610                  1     25-44     Male                     BLACK
# 63611                  0     25-44     Male                     BLACK
# 63614                  3     45-64     Male  ASIAN / PACIFIC ISLANDER
# 63615                  0     18-24     Male                     BLACK
# 63618                  0     25-44     Male                     BLACK
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0          996342      236149  40.814845 -73.956312
# 1         1003509      185018  40.674496 -73.930571
# 4         1002457      192292  40.694456 -73.934343
# 5         1046315      187088  40.679981 -73.776234
# 9         1013037      236657  40.816206 -73.896001
# ...           ...         ...        ...        ...
# 63610      989819      204094  40.726866 -73.979908
# 63611      986506      214124  40.754399 -73.991856
# 63614     1046315      187088  40.679981 -73.776234
# 63615     1011063      180396  40.661782 -73.903353
# 63618     1008227      183789  40.671104 -73.913562
#
#                            New Georeferenced Column
# 0                      POINT (-73.956312 40.814845)
# 1        POINT (-73.9305713255961 40.6744956865259)
# 4                      POINT (-73.934343 40.694456)
# 5        POINT (-73.7762339071953 40.6799807384666)
# 9        POINT (-73.8960011932583 40.8162058439227)
# ...                                             ...
# 63610  POINT (-73.97990757169028 40.72686578692612)
# 63611                  POINT (-73.991856 40.754399)
# 63614    POINT (-73.7762339071953 40.6799807384666)
# 63615                  POINT (-73.903353 40.661782)
# 63618                  POINT (-73.913562 40.671104)
#
# [26650 rows x 19 columns]

# %%
df.loc[df['LAW_CAT_CD'] == 'I'] #Traffic

# %%
df.loc[df['LAW_CAT_CD'] == '9']
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 126     280561265  2024-01-15  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 261     280775790  2024-01-19  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 497     280690858  2024-01-17  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 1017    281103899  2024-01-25  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 2027    279954060  2024-01-04  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# ...           ...         ...    ...                             ...    ...
# 61454   283343080  2024-03-07  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 62599   284433795  2024-03-27  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 62976   283624674  2024-03-12  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 63177   284323723  2024-03-26  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
# 63312   284137207  2024-03-21  849.0  NY STATE LAWS,UNCLASSIFIED VIO  677.0
#
#               OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO ARREST_PRECINCT  \
# 126    OTHER STATE LAWS  CPL5700600          9      Queens             113
# 261    OTHER STATE LAWS  CPL5700600          9      Queens             113
# 497    OTHER STATE LAWS  CPL5700600          9      Queens             113
# 1017   OTHER STATE LAWS  CPL5700600          9      Queens             102
# 2027   OTHER STATE LAWS  CPL5700600          9      Queens             113
# ...                 ...         ...        ...         ...             ...
# 61454  OTHER STATE LAWS  CPL5700600          9      Queens             114
# 62599  OTHER STATE LAWS  CPL5700600          9      Queens             113
# 62976  OTHER STATE LAWS  CPL5700600          9      Queens             113
# 63177  OTHER STATE LAWS  CPL5700600          9      Queens             107
# 63312  OTHER STATE LAWS  CPL5700600          9      Queens             102
#
#        JURISDICTION_CODE AGE_GROUP PERP_SEX                 PERP_RACE  \
# 126                    3     25-44     Male                     WHITE
# 261                    3     45-64     Male                     WHITE
# 497                    3     25-44   Female  ASIAN / PACIFIC ISLANDER
# 1017                   0     25-44   Female                     BLACK
# 2027                   3     18-24     Male                     BLACK
# ...                  ...       ...      ...                       ...
# 61454                  0     25-44     Male                     BLACK
# 62599                  3     25-44     Male            WHITE HISPANIC
# 62976                  3     25-44     Male                     BLACK
# 63177                  0     45-64     Male                     BLACK
# 63312                  0     45-64     Male                     WHITE
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 126       1046315      187088  40.679981 -73.776234
# 261       1046315      187088  40.679981 -73.776234
# 497       1046315      187088  40.679981 -73.776234
# 1017      1032501      198800  40.712206 -73.825952
# 2027      1046315      187088  40.679981 -73.776234
# ...           ...         ...        ...        ...
# 61454     1016256      226893  40.789387 -73.884416
# 62599     1046315      187088  40.679981 -73.776234
# 62976     1046315      187088  40.679981 -73.776234
# 63177     1036628      204948  40.729059 -73.811018
# 63312     1032501      198800  40.712206 -73.825952
#
#                          New Georeferenced Column
# 126    POINT (-73.7762339071953 40.6799807384666)
# 261    POINT (-73.7762339071953 40.6799807384666)
# 497    POINT (-73.7762339071953 40.6799807384666)
# 1017                 POINT (-73.825952 40.712206)
# 2027   POINT (-73.7762339071953 40.6799807384666)
# ...                                           ...
# 61454                POINT (-73.884416 40.789387)
# 62599  POINT (-73.7762339071953 40.6799807384666)
# 62976  POINT (-73.7762339071953 40.6799807384666)
# 63177                POINT (-73.811018 40.729059)
# 63312                POINT (-73.825952 40.712206)
#
# [155 rows x 19 columns]

# %%
law_cat = {
    'F': 'Felony',
    'M': 'Misdemeanor',
    'V': 'Violation',
    '9': 'Unclassified Violation',
    'I': 'Traffic'
}

# Convert 'PERP_SEX' to categorical data type
df['LAW_CAT_CD'] = df['LAW_CAT_CD'].astype('category')

# Rename categories using the dictionary
df['LAW_CAT_CD'] = df['LAW_CAT_CD'].cat.rename_categories(law_cat)

# %%
df['JURISDICTION_CODE'].unique()
# Out:
# array([ 0,  2, 17,  1,  3, 97, 73, 72, 71, 87, 51, 11,  7, 14, 12, 52, 79,
#         4, 88, 13, 69, 85, 16, 76, 74], dtype=int64)

# %%
df.drop(columns=['New Georeferenced Column'] ,axis=1, inplace=True)

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       280255493  2024-01-10  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1       279805419  2024-01-02  157.0                          RAPE 1  104.0
# 2       279895750  2024-01-03  101.0                       ASSAULT 3  344.0
# 3       280809090  2024-01-19  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4       280357135  2024-01-11  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...           ...         ...    ...                             ...    ...
# 63616   282877412  2024-02-27  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 63617   283628088  2024-03-12  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 63618   283387006  2024-03-07  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 63619   283013910  2024-03-01  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 63620   283495531  2024-03-10  203.0            TRESPASS 3, CRIMINAL  352.0
#
#                           OFNS_DESC    LAW_CODE   LAW_CAT_CD    ARREST_BORO  \
# 0                           ROBBERY  PL 1601001       Felony      Manhattan
# 1                              RAPE  PL 1303501       Felony       Brooklyn
# 2      ASSAULT 3 & RELATED OFFENSES  PL 1200001  Misdemeanor         Queens
# 3                   DANGEROUS DRUGS  PL 2200300  Misdemeanor          Bronx
# 4                    FELONY ASSAULT  PL 1200502       Felony       Brooklyn
# ...                             ...         ...          ...            ...
# 63616                 PETIT LARCENY  PL 1552500  Misdemeanor       Brooklyn
# 63617               DANGEROUS DRUGS  PL 2200300  Misdemeanor      Manhattan
# 63618                       ROBBERY  PL 160102A       Felony       Brooklyn
# 63619      VEHICLE AND TRAFFIC LAWS  VTL05110A4  Misdemeanor       Brooklyn
# 63620             CRIMINAL TRESPASS  PL 140100A  Misdemeanor  Staten Island
#
#       ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                  26                  0       <18     Male           BLACK
# 1                  77                  0     25-44     Male  WHITE HISPANIC
# 2                 106                  0       65+   Female           WHITE
# 3                  49                  0     45-64     Male           BLACK
# 4                  81                  2     25-44   Female           BLACK
# ...               ...                ...       ...      ...             ...
# 63616              60                  0     45-64     Male  WHITE HISPANIC
# 63617              13                  0     45-64     Male           BLACK
# 63618              73                  0     25-44     Male           BLACK
# 63619              83                  0     25-44   Female           BLACK
# 63620             123                  0     25-44     Male           WHITE
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude
# 0          996342      236149  40.814845 -73.956312
# 1         1003509      185018  40.674496 -73.930571
# 2         1026836      180689  40.662526 -73.846499
# 3         1027430      251104  40.855793 -73.843908
# 4         1002457      192292  40.694456 -73.934343
# ...           ...         ...        ...        ...
# 63616      987154      149165  40.576100 -73.989545
# 63617      985689      208933  40.740151 -73.994805
# 63618     1008227      183789  40.671104 -73.913562
# 63619     1007120      193913  40.698894 -73.917522
# 63620      930842      133050  40.531707 -74.192126
#
# [63210 rows x 18 columns]

# %%
df['AGE_GROUP'] = df['AGE_GROUP'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63210 entries, 0 to 63620
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ARREST_KEY         63210 non-null  int64
#  1   ARREST_DATE        63210 non-null  datetime64[ns]
#  2   PD_CD              63210 non-null  float64
#  3   PD_DESC            63210 non-null  object
#  4   KY_CD              63210 non-null  float64
#  5   OFNS_DESC          63210 non-null  object
#  6   LAW_CODE           63210 non-null  object
#  7   LAW_CAT_CD         63210 non-null  category
#  8   ARREST_BORO        63210 non-null  category
#  9   ARREST_PRECINCT    63210 non-null  category
#  10  JURISDICTION_CODE  63210 non-null  int64
#  11  AGE_GROUP          63210 non-null  category
#  12  PERP_SEX           63210 non-null  category
#  13  PERP_RACE          63210 non-null  object
#  14  X_COORD_CD         63210 non-null  int64
#  15  Y_COORD_CD         63210 non-null  int64
#  16  Latitude           63210 non-null  float64
#  17  Longitude          63210 non-null  float64
# dtypes: category(5), datetime64[ns](1), float64(4), int64(4), object(4)
# memory usage: 7.1+ MB

# %%
df['OFNS_DESC'] = df['OFNS_DESC'].astype('string')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'o'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df['OFNS_DESC'] = df['o']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'o'
